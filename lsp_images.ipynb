# %%
run datasets/lsp12000_train.py
# Out:
# 12000
# length of annotation: (14, 3, 12000)
# the length of the dataset 11000
# 0.004492836999997252
# end : 0.09051088600000057
# tensor(0.)
# tensor(1.)
# 0.0
# 1.2
# 0.02986910599999959
# end : 0.1621178950000015
# tensor(0.)
# tensor(1.)
# 0.0
# 1.2080855
# 0.01599921600000087
# end : 0.2530047620000033
# tensor(0.)
# tensor(1.)
# 0.0
# 2.0906417
# 0.006155491000001234
# end : 0.13480342800000145
# tensor(0.)
# tensor(1.)
# 0.0
# 1.2
# 0.004837444999999718
# end : 0.09184515899999823
# tensor(0.)
# tensor(1.)
# 0.0
# 1.2002442
# 0.020077256000000432
# end : 0.18461338599999877
# tensor(0.)
# tensor(1.)
# 0.0
# 1.2004032
# 0.005267628000002134
# end : 0.10224219999999917
# tensor(0.)
# tensor(1.)
# 0.0
# 1.2002469
# 0.03003521799999831
# end : 0.12785755699999868
# tensor(0.)
# tensor(0.9412)
# 0.0
# 2.4
# 0.019366315999999273
# end : 0.1369843589999995
# tensor(0.)
# tensor(1.)
# 0.0
# 1.2
# 0.005316737999997656
# end : 0.11523517399999861
# tensor(0.)
# tensor(1.)
# 0.0
# ...
