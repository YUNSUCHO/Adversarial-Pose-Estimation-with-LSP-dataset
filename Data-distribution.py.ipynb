# %%
from os.path import join
import argparse

from glob import glob
import cv2
from scipy.io import loadmat
import torch
from torch.utils.data import Dataset
from matplotlib import pyplot as plt
import numpy as np


path_s  ='/home/ycho/Adversarial-Pose-Estimation.lsp.V.4/lspet_dataset' 
path ='/home/ycho/Adversarial-Pose-EstimationV.2/lsp_dataset/'



annot = np.concatenate((loadmat(join(path, 'joints.mat'))['joints'].transpose(1 , 0 , 2), 
                                            loadmat(join(path_s, 'joints.mat'))['joints']) , axis =2)

print(annot.shape)



arr =[]
for idx in range(0 , 12000):
    for part in range(len(annot)):
        
        if part == 0 and annot[0][0][idx] !=0:
            arr.append("Right ankle")
        elif part == 1  and annot[1][0][idx] !=0:
            arr.append("Right knee")
        elif part == 2  and annot[2][0][idx] !=0:
            arr.append("Right hip")
        elif part == 3  and annot[3][0][idx] !=0:
            arr.append("Left hip")
        elif part == 4  and annot[4][0][idx] !=0:
            arr.append("Left knee")
        elif part == 5  and annot[5][0][idx] !=0:
            arr.append("Left ankle")
        elif part == 6  and annot[6][0][idx] !=0:
            arr.append("Right wrist")
        elif part == 7  and annot[7][0][idx] !=0:
            arr.append("Right elbow")
        elif part == 8  and annot[8][0][idx] !=0:
            arr.append("Right shoulder")
        elif part == 9  and annot[9][0][idx] !=0:
            arr.append("Left shoulder")
        elif part == 10 and annot[10][0][idx] !=0:
            arr.append("Left elbow")
        elif part == 11 and annot[11][0][idx] !=0:
            arr.append("Left wrist")
        elif part == 12 and annot[12][0][idx] !=0:
            arr.append("Neck")
        elif part == 13 and annot[13][0][idx] !=0:
            arr.append("Head top")
    
print(len(arr))





import seaborn as sns
sns.set_style("darkgrid")
fig_dims = (20, 15)
fig, ax = plt.subplots(figsize=fig_dims)
sns.countplot( y = arr)

plt.title('TOATAL NUMBER OF KEYPOINTS IN  THE LSP DATSET FOR EACH OF THE 14 LANDMARK ',
         fontsize =30 
         )
plt.xlabel ('COUNTS',fontsize =24)
plt.ylabel ('NAME OF THE LANDMARK',fontsize =24)
for p in ax.patches:
    percentage ='{:,.0f}'.format(p.get_width())
    width, height =p.get_width(),p.get_height()
    x=p.get_x()+width+0.02
    y=p.get_y()+height/2
    ax.annotate(percentage,(x,y), fontsize = 30)
# Out:
# (14, 3, 12000)
# 157568

# %%
from os.path import join
import argparse

from glob import glob
import cv2
from scipy.io import loadmat
import torch
from torch.utils.data import Dataset
from matplotlib import pyplot as plt
import numpy as np


path_s  ='/home/ycho/Adversarial-Pose-Estimation.lsp.V.4/lspet_dataset' 
path ='/home/ycho/Adversarial-Pose-EstimationV.2/lsp_dataset/'



annot = np.concatenate((loadmat(join(path, 'joints.mat'))['joints'].transpose(1 , 0 , 2), 
                                            loadmat(join(path_s, 'joints.mat'))['joints']) , axis =2)

print(annot.shape)



arr =[]
for idx in range(0 , 11000):
    for part in range(len(annot)):
        
        if part == 0 and annot[0][0][idx] !=0:
            arr.append("Right ankle")
        elif part == 1  and annot[1][0][idx] !=0:
            arr.append("Right knee")
        elif part == 2  and annot[2][0][idx] !=0:
            arr.append("Right hip")
        elif part == 3  and annot[3][0][idx] !=0:
            arr.append("Left hip")
        elif part == 4  and annot[4][0][idx] !=0:
            arr.append("Left knee")
        elif part == 5  and annot[5][0][idx] !=0:
            arr.append("Left ankle")
        elif part == 6  and annot[6][0][idx] !=0:
            arr.append("Right wrist")
        elif part == 7  and annot[7][0][idx] !=0:
            arr.append("Right elbow")
        elif part == 8  and annot[8][0][idx] !=0:
            arr.append("Right shoulder")
        elif part == 9  and annot[9][0][idx] !=0:
            arr.append("Left shoulder")
        elif part == 10 and annot[10][0][idx] !=0:
            arr.append("Left elbow")
        elif part == 11 and annot[11][0][idx] !=0:
            arr.append("Left wrist")
        elif part == 12 and annot[12][0][idx] !=0:
            arr.append("Neck")
        elif part == 13 and annot[13][0][idx] !=0:
            arr.append("Head top")
    
print(len(arr))





import seaborn as sns
sns.set_style("darkgrid")
fig_dims = (20, 15)
fig, ax = plt.subplots(figsize=fig_dims)
sns.countplot( y = arr)

plt.title('TOATAL NUMBER OF KEYPOINTS IN  THE LSP TRAINING DATSET FOR EACH OF THE 14 LANDMARK ',
         fontsize =30 
         )
plt.xlabel ('COUNTS',fontsize =24)
plt.ylabel ('NAME OF THE LANDMARK',fontsize =24)
for p in ax.patches:
    percentage ='{:,.0f}'.format(p.get_width())
    width, height =p.get_width(),p.get_height()
    x=p.get_x()+width+0.02
    y=p.get_y()+height/2
    ax.annotate(percentage,(x,y), fontsize = 30)
# Out:
# (14, 3, 12000)
# 144562

# %%
from os.path import join
import argparse

from glob import glob
import cv2
from scipy.io import loadmat
import torch
from torch.utils.data import Dataset
from matplotlib import pyplot as plt
import numpy as np


path_s  ='/home/ycho/Adversarial-Pose-Estimation.lsp.V.4/lspet_dataset' 
path ='/home/ycho/Adversarial-Pose-EstimationV.2/lsp_dataset/'



annot = np.concatenate((loadmat(join(path, 'joints.mat'))['joints'].transpose(1 , 0 , 2), 
                                            loadmat(join(path_s, 'joints.mat'))['joints']) , axis =2)



annot_1 = np.concatenate((loadmat(join(path_s, 'joints.mat'))['joints'], 
                                            loadmat(join(path, 'joints.mat'))['joints'].transpose(1 , 0 , 2)) , axis =2)

print(annot_1.shape)

annot = annot_1[:,:,11000:12000]
print(annot.shape)

arr =[]
for idx in range(0 , 1000):
    for part in range(len(annot)):
        
        if part == 0 and annot[0][0][idx] !=0:
            arr.append("Right ankle")
        elif part == 1  and annot[1][0][idx] !=0:
            arr.append("Right knee")
        elif part == 2  and annot[2][0][idx] !=0:
            arr.append("Right hip")
        elif part == 3  and annot[3][0][idx] !=0:
            arr.append("Left hip")
        elif part == 4  and annot[4][0][idx] !=0:
            arr.append("Left knee")
        elif part == 5  and annot[5][0][idx] !=0:
            arr.append("Left ankle")
        elif part == 6  and annot[6][0][idx] !=0:
            arr.append("Right wrist")
        elif part == 7  and annot[7][0][idx] !=0:
            arr.append("Right elbow")
        elif part == 8  and annot[8][0][idx] !=0:
            arr.append("Right shoulder")
        elif part == 9  and annot[9][0][idx] !=0:
            arr.append("Left shoulder")
        elif part == 10 and annot[10][0][idx] !=0:
            arr.append("Left elbow")
        elif part == 11 and annot[11][0][idx] !=0:
            arr.append("Left wrist")
        elif part == 12 and annot[12][0][idx] !=0:
            arr.append("Neck")
        elif part == 13 and annot[13][0][idx] !=0:
            arr.append("Head top")
    
print(len(arr))





import seaborn as sns
sns.set_style("darkgrid")
fig_dims = (20, 15)
fig, ax = plt.subplots(figsize=fig_dims)
sns.countplot( y = arr)

plt.title('TOATAL NUMBER OF KEYPOINTS IN  THE LSP TESTING DATSET FOR EACH OF THE 14 LANDMARK ',
         fontsize =30 
         )
plt.xlabel ('COUNTS',fontsize =24)
plt.ylabel ('NAME OF THE LANDMARK',fontsize =24)
for p in ax.patches:
    percentage ='{:,.0f}'.format(p.get_width())
    width, height =p.get_width(),p.get_height()
    x=p.get_x()+width+0.02
    y=p.get_y()+height/2
    ax.annotate(percentage,(x,y), fontsize = 30)
# Out:
# (14, 3, 12000)
# (14, 3, 1000)
# 14000

# %%
from os.path import join
import argparse

from glob import glob
import cv2
from scipy.io import loadmat
import torch
from torch.utils.data import Dataset
from matplotlib import pyplot as plt
import numpy as np
import h5py as  H




path ='/home/ycho/Adversarial-Pose-Estimation/mpii/images/'
f = H.File('/home/ycho/Adversarial-Pose-Estimation/mpii/pureannote/train.h5', 'r')

tags = ['imgname','part','center','scale']


annot = np.asarray(f['part']).copy()[0:11000].transpose(1 , 2 , 0) #need to comment out when test the model
#print(annot[tag]) ##originally not there
print(annot.shape)





arr =[]
for idx in range(0 , 11000):
    for part in range(len(annot)):
        
        if part == 0  and   annot[0][0][idx] !=0:
            arr.append("Right ankle")
        elif part == 1  and annot[1][0][idx] !=0:
            arr.append("Right knee")
        elif part == 2  and annot[2][0][idx] !=0:
            arr.append("Right hip")
        elif part == 3  and annot[3][0][idx] !=0:
            arr.append("Left hip")
        elif part == 4  and annot[4][0][idx] !=0:
            arr.append("Left knee")
        elif part == 5  and annot[5][0][idx] !=0:
            arr.append("Left ankle")
        elif part == 6  and annot[6][0][idx] !=0:
            arr.append("Pelvis")
        elif part == 7  and annot[7][0][idx] !=0:
            arr.append("Thorax")
        elif part == 8  and annot[8][0][idx] !=0:
            arr.append("Upper neck")
        elif part == 9  and annot[9][0][idx] !=0:
            arr.append("Head top")
        elif part == 10  and annot[10][0][idx] !=0:
            arr.append("Right wrist")
        elif part == 11  and annot[11][0][idx] !=0:
            arr.append("Right elbow")
        elif part == 12  and annot[12][0][idx] !=0:
            arr.append("Right shoulder")
        elif part == 13  and annot[13][0][idx] !=0:
            arr.append("Left shoulder")
        elif part == 14  and annot[14][0][idx] !=0:
            arr.append("Left elbow")
        elif part == 15  and annot[15][0][idx] !=0:
            arr.append("Left wrist")
            
    



import seaborn as sns
sns.set_style("darkgrid")
fig_dims = (20, 15)
fig, ax = plt.subplots(figsize=fig_dims)
sns.countplot( y = arr)

plt.title('TOATAL NUMBER OF KEYPOINTS IN  THE MPII DATSET FOR EACH OF THE 14 LANDMARK ',
         fontsize =30 
         )
plt.xlabel ('COUNTS',fontsize =24)
plt.ylabel ('NAME OF THE LANDMARK',fontsize =24)
for p in ax.patches:
    percentage ='{:,.0f}'.format(p.get_width())
    width, height =p.get_width(),p.get_height()
    x=p.get_x()+width+0.02
    y=p.get_y()+height/2
    ax.annotate(percentage,(x,y), fontsize = 30)
# Out:
# (16, 2, 11000)
